# %%
import yfinance as yf
import pandas as pd
import sqlite3
import requests
from bs4 import BeautifulSoup

# pd.set_option("display.max_rows", None)

# %% [markdown]
# Scrape ticker symbols of S&P500 stocks

# %%
# Set the User-Agent header to a string that mimics a popular web browser to get past firewall rules
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
# Request and parse the web page
r = requests.get("https://www.slickcharts.com/sp500", headers=headers)
soup = BeautifulSoup(r.text, "lxml")
# Extract the text (replacing . with -) from the third cell (Symbol column) of each row of the main table
# (ordered by component weights)
ticker_symbols = [
    tr.find_all("td")[2].text.replace(".", "-")
    for tr in soup.find("tbody").find_all("tr")
]
ticker_symbols[:10]
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'NVDA',
#  'GOOGL',
#  'GOOG',
#  'META',
#  'BRK-B',
#  'TSLA',
#  'UNH']

# %% [markdown]
# Create database

# %%
con = sqlite3.connect("stonks.db")
cur = con.cursor()

# %%
def create_tables(drop=False):
    create_tables = """
    CREATE TABLE IF NOT EXISTS exchange (
        id INTEGER PRIMARY KEY NOT NULL,
        name TEXT NOT NULL UNIQUE
    );
    CREATE TABLE IF NOT EXISTS ticker_type (
        id INTEGER PRIMARY KEY NOT NULL,
        name TEXT NOT NULL UNIQUE
    );
    CREATE TABLE IF NOT EXISTS sector (
        id INTEGER PRIMARY KEY NOT NULL,
        name TEXT NOT NULL UNIQUE
    );
    CREATE TABLE IF NOT EXISTS currency (
        id INTEGER PRIMARY KEY NOT NULL,
        iso_code TEXT NOT NULL UNIQUE
    );
    CREATE TABLE IF NOT EXISTS ticker (
        id INTEGER PRIMARY KEY NOT NULL,
        currency_id INTEGER NOT NULL,
        exchange_id INTEGER NOT NULL,
        ticker_type_id INTEGER NOT NULL,
        sector_id INTEGER NOT NULL,
        symbol TEXT NOT NULL UNIQUE,
        name TEXT NOT NULL,
        FOREIGN KEY(currency_id) REFERENCES currency(id),
        FOREIGN KEY(exchange_id) REFERENCES exchange(id),
        FOREIGN KEY(ticker_type_id) REFERENCES ticker_type(id),
        FOREIGN KEY(sector_id) REFERENCES sector(id)
    );
    CREATE TABLE IF NOT EXISTS date (
        id INTEGER PRIMARY KEY NOT NULL,
        date INTEGER NOT NULL UNIQUE
    );
    CREATE TABLE IF NOT EXISTS price (
        ticker_id INTEGER NOT NULL,
        date_id INTEGER NOT NULL,
        open REAL NOT NULL,
        high REAL NOT NULL,
        low REAL NOT NULL,
        close REAL NOT NULL,
        volume INTEGER NOT NULL,
        PRIMARY KEY (ticker_id, date_id),
        FOREIGN KEY(ticker_id) REFERENCES ticker(id),
        FOREIGN KEY(date_id) REFERENCES date(id)
    );
    CREATE INDEX IF NOT EXISTS fk_ticker_idx ON ticker (
        sector_id,
        exchange_id,
        currency_id,
        ticker_type_id
    );
    """
    drop_tables = """
    DROP TABLE IF EXISTS ticker;
    DROP TABLE IF EXISTS exchange;
    DROP TABLE IF EXISTS price;
    DROP TABLE IF EXISTS date;
    DROP TABLE IF EXISTS ticker_type;
    DROP TABLE IF EXISTS sector;
    DROP TABLE IF EXISTS currency;
    """
    if drop:
        cur.executescript(drop_tables)
    cur.executescript(create_tables)
    con.commit()


# Create necessary tables
create_tables(drop=True)

# %%
# Define function to check successful index creation
# PKs and unique constrained attributes are automatically indexed
# the price tables composite PK is correctly indexed with a composite index
def list_indexes():
    # Get all tables from sqlite_master
    cur.execute(
        """
        SELECT name
        FROM sqlite_master
        WHERE TYPE = 'table';
        """
    )
    tables = cur.fetchall()
    for table in tables:
        table_name = table[0]
        # Get table info
        cur.execute(f"PRAGMA table_info({table_name});")
        columns = cur.fetchall()
        # Get index info
        cur.execute(f"PRAGMA index_list({table_name});")
        indexes = cur.fetchall()
        print("Table:", table_name)

        # Extract and display info about each individual index
        for index in indexes:
            index_name = index[1]
            unique = index[2]
            index_columns = []

            for column in columns:
                cur.execute(f"PRAGMA index_info({index_name});")
                index_info = cur.fetchall()
                for info in index_info:
                    if info[2] == column[1]:
                        index_columns.append(column[1])
            print("  Index:", index_name)
            print("    Columns:", ", ".join(index_columns))
            print("    Unique:", "Yes" if unique else "No")
        print()


list_indexes()
# Out:
# Table: exchange
#   Index: sqlite_autoindex_exchange_1
#     Columns: name
#     Unique: Yes
#
# Table: ticker_type
#   Index: sqlite_autoindex_ticker_type_1
#     Columns: name
#     Unique: Yes
#
# Table: sector
#   Index: sqlite_autoindex_sector_1
#     Columns: name
#     Unique: Yes
#
# Table: currency
#   Index: sqlite_autoindex_currency_1
#     Columns: iso_code
#     Unique: Yes
#
# Table: ticker
#   Index: fk_ticker_idx
#     Columns: currency_id, exchange_id, ticker_type_id, sector_id
#     Unique: No
#   Index: sqlite_autoindex_ticker_1
#     Columns: symbol
#     Unique: Yes
#
# Table: date
#   Index: sqlite_autoindex_date_1
#     Columns: date
#     Unique: Yes
#
# Table: price
#   Index: sqlite_autoindex_price_1
#     Columns: ticker_id, date_id
#     Unique: Yes

# %% [markdown]
# Download market data from Yahoo! Finance's API (experiments)

# %%
ticker = yf.Ticker("BRK-B")
info = ticker.info
cols = [
    "symbol",
    "shortName",
    "sector",
    "exchange",
    "quoteType",
    "timeZoneShortName",
    "gmtOffSetMilliseconds",
    "currency",
]

pd.DataFrame(info).iloc[0][cols].to_frame()
# Out:
#                                                  0
# symbol                                       BRK-B
# shortName              Berkshire Hathaway Inc. New
# sector                          Financial Services
# exchange                                       NYQ
# quoteType                                   EQUITY
# timeZoneShortName                              EDT
# gmtOffSetMilliseconds                    -14400000
# currency                                       USD

# %%
# Initiate tickers instance
tickers = yf.Tickers(" ".join(ticker_symbols))

# %%
# Download data and convert index timestamp to unix (seconds) for convenient storage in database
temp = tickers.download(group_by="ticker", start="2023-07-01")
temp.drop(columns=["Dividends", "Stock Splits"], level=1, inplace=True)
temp.index = temp.index.astype("datetime64[s]").astype(int)
[(unix,) for unix in temp.index][:10]
# Out:
# [*********************100%***********************]  504 of 504 completed
# [(1688342400,),
#  (1688515200,),
#  (1688601600,),
#  (1688688000,),
#  (1688947200,),
#  (1689033600,),
#  (1689120000,),
#  (1689206400,),
#  (1689292800,),
#  (1689552000,)]

# %%
# Verify correct datetime
pd.to_datetime(temp.index, unit="s")
# Out:
# DatetimeIndex(['2023-07-03', '2023-07-05', '2023-07-06', '2023-07-07',
#                '2023-07-10', '2023-07-11', '2023-07-12', '2023-07-13',
#                '2023-07-14', '2023-07-17', '2023-07-18', '2023-07-19',
#                '2023-07-20', '2023-07-21', '2023-07-24', '2023-07-25',
#                '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-31',
#                '2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10',
#                '2023-08-11', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# Download necessary data and fill ticker and it's reference (parent) tables

# %%
# Fill database with ticker information
for symbol in ticker_symbols:
    try:
        with con:
            info = tickers.tickers[symbol].info
            con.execute(
                """
                INSERT
                    OR IGNORE INTO currency (iso_code)
                VALUES (:currency)
                """,
                info,
            )
            con.execute(
                """
                INSERT
                    OR IGNORE INTO exchange (name)
                VALUES (:exchange)
                """,
                info,
            )
            con.execute(
                """
                INSERT
                    OR IGNORE INTO ticker_type (name)
                VALUES (:quoteType)
                """,
                info,
            )
            con.execute(
                """
                INSERT
                    OR IGNORE INTO sector (name)
                VALUES (:sector)
                """,
                info,
            )
            con.execute(
                """
                INSERT INTO ticker (
                        name,
                        symbol,
                        currency_id,
                        exchange_id,
                        ticker_type_id,
                        sector_id
                    )
                VALUES (
                        :shortName,
                        :symbol,
                        (
                            SELECT id
                            FROM currency
                            WHERE iso_code = :currency
                        ),
                        (
                            SELECT id
                            FROM exchange
                            WHERE name = :exchange
                        ),
                        (
                            SELECT id
                            FROM ticker_type
                            WHERE name = :quoteType
                        ),
                        (
                            SELECT id
                            FROM sector
                            WHERE name = :sector
                        )
                    )
                """,
                info,
            )
            print(symbol)
    except:
        print(f"failed to insert {symbol}")
# Out:
# AAPL
# MSFT
# AMZN
# NVDA
# GOOGL
# GOOG
# META
# BRK-B
# TSLA
# UNH
# JNJ
# XOM
# JPM
# LLY
# V
# PG
# AVGO
# HD
# MA
# CVX
# MRK
# ABBV
# PEP
# COST
# KO
# ADBE
# CSCO
# WMT
# TMO
# PFE
# MCD
# BAC
# CRM
# ACN
# CMCSA
# LIN
# ABT
# NFLX
# ORCL
# AMD
# DHR
# WFC
# DIS
# TXN
# PM
# failed to insert CAT
# COP
# AMGN
# VZ
# UNP
# INTU
# NEE
# INTC
# BMY
# LOW
# NKE
# IBM
# BA
# SPGI
# RTX
# HON
# UPS
# QCOM
# GE
# AMAT
# BKNG
# DE
# MS
# SBUX
# NOW
# PLD
# ELV
# GS
# MDT
# ADP
# TJX
# ISRG
# BLK
# LMT
# T
# MDLZ
# AXP
# GILD
# SYK
# MMC
# ADI
# SCHW
# VRTX
# LRCX
# CVS
# REGN
# ETN
# ZTS
# CB
# C
# SLB
# AMT
# CI
# PGR
# TMUS
# DPZ
# PAYC
# APA
# MOS
# EPAM
# LW
# TRMB
# PKG
# LKQ
# KMX
# LDOS
# EVRG
# WDC
# MGM
# MAS
# TECH
# LNT
# STX
# WRB
# NDSN
# MTCH
# IPG
# IP
# BF-B
# AES
# failed to insert L
# LYV
# INCY
# UDR
# CPT
# CE
# TAP
# KIM
# GEN
# HRL
# HST
# JKHY
# CZR
# FMC
# PEAK
# CHRW
# PNR
# NI
# CDAY
# TFX
# HSIC
# CRL
# GL
# KEY
# EMN
# WYNN
# QRVO
# AAL
# REG
# ETSY
# ALLE
# BWA
# MKTX
# ROL
# FFIV
# SEDG
# JNPR
# AOS
# FOXA
# BXP
# HII
# PNW
# NRG
# CPB
# TPR
# WRK
# BBWI
# UHS
# BIO
# RHI
# HAS
# NWSA
# XRAY
# CTLT
# AIZ
# BEN
# PARA
# WHR
# FRT
# IVZ
# NCLH
# GNRC
# VFC
# CMA
# OGN
# DVA
# ALK
# ZION
# SEE
# MHK
# RL
# DXC
# FOX
# AAP
# LNC
# NWL
# NWS
# FTRE

# %% [markdown]
# Compare batch download and per ticker data retrieval

# %%
# %%script echo ≈x3 times faster execution, but higher CPU time ᘇᘏᗢ、
# %%time
# # Batch retrieve OHLC data
# data = tickers.download(start="2022-07-01", end="2023-07-01", group_by="ticker")
# data.drop(columns=["Dividends", "Stock Splits"], level=1, inplace=True)
# # Convert the date to a unix timestamp (seconds)
# data.index = data.index.astype("datetime64[s]").astype(int)
# # Inserting date
# con.executemany(
#     """
# INSERT
#     OR IGNORE INTO date (date)
# VALUES (?)
# """,
#     [(unix,) for unix in data.index],
# )
#
# for symbol in cur.execute(
#     """
# SELECT symbol
# FROM ticker
# """
# ).fetchall():
#     try:
#         # Retrieve OHLC data for symbol
#         ohlc_data = data[symbol[0]].reset_index()
#         # Convert to a list of dictionaries (records)
#         ohlc_data = ohlc_data.to_dict(orient="records")
#         with con:
#             # Using an f-string is an SQL injection vulnerability,
#             # but given the context it doesn't matter
#             con.executemany(
#                 f"""
#             INSERT INTO price (
#                     ticker_id,
#                     date_id,
#                     OPEN,
#                     high,
#                     low,
#                     close,
#                     volume
#                 )
#             VALUES (
#                     (
#                         SELECT id
#                         FROM ticker
#                         WHERE symbol = '{symbol[0]}'
#                     ),
#                     (
#                         SELECT id
#                         FROM date
#                         WHERE date = :Date
#                     ),
#                     :Open,
#                     :High,
#                     :Low,
#                     :Close,
#                     :Volume
#                 )
#             """,
#                 ohlc_data,
#             )
#             print(symbol[0])
#     except Exception as e:
#         print(f"[{symbol[0]}] {e}")
# Out:
# ≈x3 times faster execution, but higher CPU time ᘇᘏᗢ、

# %%
# %%script echo lower CPU time, but ≈x3 times slower execution ᘇᘏᗢ、
# %%time
# # Per ticker OHLC data retrieval - helps avoid rate limiting
# for symbol in cur.execute(
#     """
#     SELECT symbol
#     FROM ticker
#     """
# ).fetchall():
#     try:
#         # Retrieve OHLC data for symbol
#         ohlc_data = tickers.tickers[symbol[0]].history(
#             start="2022-07-01", end="2023-07-01"
#         )[["Open", "High", "Low", "Close", "Volume"]]
#         # Convert the date to a unix timestamp (remove timezone holding local time representations)
#         ohlc_data.index = ohlc_data.index.tz_localize(None).astype("int") / 10**9
#         ohlc_data.reset_index(inplace=True)
#         # Convert to a list of dictionaries (records)
#         ohlc_data = ohlc_data.to_dict(orient="records")
#         with con:
#             # Inserting date could be optimized
#             con.executemany(
#                 """
#                 INSERT
#                     OR IGNORE INTO date (date)
#                 VALUES (:Date)
#                 """,
#                 ohlc_data,
#             )
#
#             # Using an f-string is an SQL injection vulnerability,
#             # but given the context it doesn't matter
#             con.executemany(
#                 f"""
#                 INSERT INTO price (
#                         ticker_id,
#                         date_id,
#                         OPEN,
#                         high,
#                         low,
#                         close,
#                         volume
#                     )
#                 VALUES (
#                         (
#                             SELECT id
#                             FROM ticker
#                             WHERE symbol = '{symbol[0]}'
#                         ),
#                         (
#                             SELECT id
#                             FROM date
#                             WHERE date = :Date
#                         ),
#                         :Open,
#                         :High,
#                         :Low,
#                         :Close,
#                         :Volume
#                     )
#             """,
#                 ohlc_data,
#             )
#             print(symbol[0])
#     except Exception as e:
#         print(f"[{symbol[0]}] {e}")
# Out:
# lower CPU time, but ≈x3 times slower execution ᘇᘏᗢ、

# %% [markdown]
# Download data and fill date and price tables

# %%
# Per ticker OHLC data retrieval - helps avoid rate limiting
for symbol in cur.execute(
    """
    SELECT symbol
    FROM ticker
    """
).fetchall():
    try:
        # Retrieve OHLC data for symbol
        ohlc_data = tickers.tickers[symbol[0]].history(
            start="2022-07-01", end="2023-07-01"
        )[["Open", "High", "Low", "Close", "Volume"]]
        # Convert the date to a unix timestamp (remove timezone holding local time representations)
        ohlc_data.index = ohlc_data.index.tz_localize(None).astype("int") / 10**9
        ohlc_data.reset_index(inplace=True)
        # Convert to a list of dictionaries (records)
        ohlc_data = ohlc_data.to_dict(orient="records")
        with con:
            # Inserting date could be optimized
            con.executemany(
                """
                INSERT
                    OR IGNORE INTO date (date)
                VALUES (:Date)
                """,
                ohlc_data,
            )

            # Using an f-string is an SQL injection vulnerability,
            # but given the context it doesn't matter, can be easily fixed if needed
            con.executemany(
                f"""
                INSERT INTO price (
                        ticker_id,
                        date_id,
                        OPEN,
                        high,
                        low,
                        close,
                        volume
                    )
                VALUES (
                        (
                            SELECT id
                            FROM ticker
                            WHERE symbol = '{symbol[0]}'
                        ),
                        (
                            SELECT id
                            FROM date
                            WHERE date = :Date
                        ),
                        :Open,
                        :High,
                        :Low,
                        :Close,
                        :Volume
                    )
            """,
                ohlc_data,
            )
            print(symbol[0])
    except Exception as e:
        print(f"[{symbol[0]}] {e}")
# Out:
# A
# AAL
# AAP
# AAPL
# ABBV
# ABC
# ABT
# ACGL
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# AEE
# AEP
# AES
# AFL
# AIG
# AIZ
# AJG
# AKAM
# ALB
# ALGN
# ALK
# ALL
# ALLE
# AMAT
# AMCR
# AMD
# AME
# AMGN
# NKE
# NOC
# NOW
# NRG
# NSC
# NTAP
# NTRS
# NUE
# NVDA
# NVR
# NWL
# NWS
# NWSA
# NXPI
# O
# ODFL
# OGN
# OKE
# OMC
# ON
# ORCL
# ORLY
# OTIS
# OXY
# PANW
# PARA
# PAYC
# PAYX
# PCAR
# PCG
# PEAK
# PEG
# PEP
# PFE
# PFG
# PG
# PGR
# PH
# PHM
# PKG
# PLD
# PM
# PNC
# PNR
# PNW
# PODD
# POOL
# PPG
# PPL
# PRU
# PSA
# PSX
# PTC
# PWR
# PXD
# PYPL
# QCOM
# QRVO
# RCL
# REG
# REGN
# RF
# RHI
# RJF
# RL
# RMD
# ROK
# ROL
# ROP
# ROST
# RSG
# RTX
# RVTY
# SBAC
# SBUX
# SCHW
# SEDG
# SEE
# SHW
# SJM
# SLB
# SNA
# SNPS
# SO
# SPG
# SPGI
# SRE
# STE
# STLD
# STT
# STX
# STZ
# SWK
# SWKS
# SYF
# SYK
# SYY
# T
# TAP
# TDG
# TDY
# TECH
# TEL
# TER
# TFC
# TFX
# TGT
# TJX
# TMO
# TMUS
# TPR
# TRGP
# TRMB
# TROW
# TRV
# TSCO
# TSLA
# TSN
# TT
# TTWO
# TXN
# TXT
# TYL
# UAL
# UDR
# UHS
# ULTA
# UNH
# UNP
# UPS
# URI
# USB
# V
# VFC
# VICI
# VLO
# VMC
# VRSK
# VRSN
# VRTX
# VTR
# VTRS
# VZ
# WAB
# WAT
# WBA
# WBD
# WDC
# WEC
# WELL
# WFC
# WHR
# WM
# WMB
# WMT
# WRB
# WRK
# WST
# WTW
# WY
# WYNN
# XEL
# XOM
# XRAY
# XYL
# YUM
# ZBH
# ZBRA
# ZION
# ZTS

# %% [markdown]
# Create update capabilities

# %%
cur.execute(
    """
    SELECT DATE(max(date) + 86400, 'unixepoch')
    FROM price p
        JOIN ticker t ON t.id = p.ticker_id
        JOIN date d ON p.date_id = d.id
    WHERE t.symbol = 'AAPL'
    """
).fetchone()[0]
# Out:
# '2023-07-01'

# %%
# Define function for updating ohlc data for a given ticker by it's symbol
def add_new_ohlc(symbol):
    try:
        # Get date for latest entry
        latest_entry = cur.execute(
            """
            SELECT DATE(max(date) + 86400, 'unixepoch')
            FROM price p
                JOIN ticker t ON t.id = p.ticker_id
                JOIN date d ON p.date_id = d.id
            WHERE t.symbol = ?
            """,
            (symbol,),
        ).fetchone()[0]
        # Retrieve new OHLC data for symbol
        ohlc_data = tickers.tickers[symbol].history(start=latest_entry)[
            ["Open", "High", "Low", "Close", "Volume"]
        ]
        # Convert the date to a unix timestamp (remove timezone holding local time representations)
        ohlc_data.index = ohlc_data.index.tz_localize(None).astype("int") / 10**9
        ohlc_data.reset_index(inplace=True)
        # Convert to a list of dictionaries (records)
        ohlc_data = ohlc_data.to_dict(orient="records")
        with con:
            # Inserting date could be optimized
            con.executemany(
                """
                INSERT
                    OR IGNORE INTO date (date)
                VALUES (:Date)
                """,
                ohlc_data,
            )

            # Using an f-string is an SQL injection vulnerability,
            # but given the context it doesn't matter
            con.executemany(
                f"""
                INSERT INTO price (
                        ticker_id,
                        date_id,
                        OPEN,
                        high,
                        low,
                        close,
                        volume
                    )
                VALUES (
                        (
                            SELECT id
                            FROM ticker
                            WHERE symbol = '{symbol}'
                        ),
                        (
                            SELECT id
                            FROM date
                            WHERE date = :Date
                        ),
                        :Open,
                        :High,
                        :Low,
                        :Close,
                        :Volume
                    )
                """,
                ohlc_data,
            )
            print(symbol)
    except Exception as e:
        print(f"[{symbol}] {e}")


add_new_ohlc("AAPL")
# Out:
# AAPL

# %%
# Check number of entries per ticket name to confirm that update works
cur.execute(
    """
    SELECT COUNT(),
        name
    FROM price
        JOIN ticker ON ticker.id = price.ticker_id
    GROUP BY ticker.name
    """
).fetchall()
# Out:
# [(251, '3M Company'),
#  (251, 'A.O. Smith Corporation'),
#  (251, 'AFLAC Incorporated'),
#  (251, 'AMETEK, Inc.'),
#  (251, 'ANSYS, Inc.'),
#  (251, 'APA Corporation'),
#  (251, 'AT&T Inc.'),
#  (251, 'AbbVie Inc.'),
#  (251, 'Abbott Laboratories'),
#  (251, 'Accenture plc'),
#  (251, 'Activision Blizzard, Inc'),
#  (251, 'Adobe Inc.'),
#  (251, 'Advance Auto Parts Inc.'),
#  (251, 'Advanced Micro Devices, Inc.'),
#  (251, 'Agilent Technologies, Inc.'),
#  (251, 'Air Products and Chemicals, Inc'),
#  (251, 'Akamai Technologies, Inc.'),
#  (251, 'Alaska Air Group, Inc.'),
#  (251, 'Albemarle Corporation'),
#  (251, 'Alexandria Real Estate Equities'),
#  (251, 'Align Technology, Inc.'),
#  (251, 'Allegion plc'),
#  (251, 'Alliant Energy Corporation'),
#  (251, 'Allstate Corporation (The)'),
#  (502, 'Alphabet Inc.'),
#  (251, 'Altria Group, Inc.'),
#  (251, 'Amazon.com, Inc.'),
#  (251, 'Amcor plc'),
#  (251, 'Ameren Corporation'),
#  (251, 'American Airlines Group, Inc.'),
#  (251, 'American Electric Power Company'),
#  (251, 'American Express Company'),
#  (251, 'American International Group, I'),
#  (251, 'American Tower Corporation (REI'),
#  (251, 'American Water Works Company, I'),
#  (251, 'Ameriprise Financial, Inc.'),
#  (251, 'AmerisourceBergen Corporation'),
#  (251, 'Amgen Inc.'),
#  (251, 'Amphenol Corporation'),
#  (251, 'Analog Devices, Inc.'),
#  (251, 'Aon plc'),
#  (285, 'Apple Inc.'),
#  (251, 'Applied Materials, Inc.'),
#  (251, 'Aptiv PLC'),
#  (251, 'Arch Capital Group Ltd.'),
#  (251, 'Archer-Daniels-Midland Company'),
#  (251, 'Arista Networks, Inc.'),
#  (251, 'Arthur J. Gallagher & Co.'),
#  (251, 'Assurant, Inc.'),
#  (251, 'Atmos Energy Corporation'),
#  (251, 'AutoZone, Inc.'),
#  (251, 'Autodesk, Inc.'),
#  (251, 'Automatic Data Processing, Inc.'),
#  (251, 'AvalonBay Communities, Inc.'),
#  (251, 'Avery Dennison Corporation'),
#  (251, 'Corteva, Inc.'),
#  (251, 'Costco Wholesale Corporation'),
#  (251, 'Coterra Energy Inc.'),
#  (251, 'Crown Castle Inc.'),
#  (251, 'Cummins Inc.'),
#  (251, 'D.R. Horton, Inc.'),
#  (251, 'DBA Sempra'),
#  (251, 'DENTSPLY SIRONA Inc.'),
#  (251, 'DTE Energy Company'),
#  (251, 'DXC Technology Company'),
#  (251, 'DaVita Inc.'),
#  (251, 'Danaher Corporation'),
#  (251, 'Darden Restaurants, Inc.'),
#  (251, 'Deere & Company'),
#  (251, 'Delta Air Lines, Inc.'),
#  (251, 'Devon Energy Corporation'),
#  (251, 'DexCom, Inc.'),
#  (251, 'Diamondback Energy, Inc.'),
#  (251, 'Digital Realty Trust, Inc.'),
#  (251, 'Discover Financial Services'),
#  (251, 'Dollar General Corporation'),
#  (251, 'Dollar Tree, Inc.'),
#  (251, 'Dominion Energy, Inc.'),
#  (251, "Domino's Pizza Inc"),
#  (251, 'Dover Corporation'),
#  (251, 'Dow Inc.'),
#  (251, 'DuPont de Nemours, Inc.'),
#  (251, 'Duke Energy Corporation (Holdin'),
#  (251, 'EOG Resources, Inc.'),
#  (251, 'EPAM Systems, Inc.'),
#  (251, 'EQT Corporation'),
#  (251, 'Eastman Chemical Company'),
#  (251, 'Eaton Corporation, PLC'),
#  (251, 'Ecolab Inc.'),
#  (251, 'Edison International'),
#  (251, 'Edwards Lifesciences Corporatio'),
#  (251, 'Electronic Arts Inc.'),
#  (251, 'Elevance Health, Inc.'),
#  (251, 'Eli Lilly and Company'),
#  (251, 'Emerson Electric Company'),
#  (251, 'Enphase Energy, Inc.'),
#  (251, 'Entergy Corporation'),
#  (251, 'Equifax, Inc.'),
#  (251, 'Equinix, Inc.'),
#  (251, 'Equity Residential'),
#  (251, 'Essex Property Trust, Inc.'),
#  (251, 'Estee Lauder Companies, Inc. (T'),
#  (251, 'Etsy, Inc.'),
#  (251, 'Everest Group, Ltd.'),
#  (251, 'Evergy, Inc.'),
#  (251, 'Eversource Energy (D/B/A)'),
#  (251, 'Exelon Corporation'),
#  (251, 'Expedia Group, Inc.'),
#  (251, 'Expeditors International of Was'),
#  (251, 'Extra Space Storage Inc'),
#  (251, 'Exxon Mobil Corporation'),
#  (251, 'F5, Inc.'),
#  (251, 'FMC Corporation'),
#  (251, 'FactSet Research Systems Inc.'),
#  (251, 'Fair Isaac Corproation'),
#  (251, 'Fastenal Company'),
#  (251, 'FedEx Corporation'),
#  (251, 'Federal Realty Investment Trust'),
#  (251, 'Fidelity National Information S'),
#  (251, 'Fifth Third Bancorp'),
#  (251, 'First Solar, Inc.'),
#  (251, 'FirstEnergy Corp.'),
#  (251, 'Fiserv, Inc.'),
#  (251, 'FleetCor Technologies, Inc.'),
#  (251, 'Ford Motor Company'),
#  (251, 'Fortinet, Inc.'),
#  (251, 'Fortive Corporation'),
#  (9, 'Fortrea Holdings Inc.'),
#  (502, 'Fox Corporation'),
#  (251, 'Franklin Resources, Inc.'),
#  (251, 'Freeport-McMoRan, Inc.'),
#  (135, 'GE HealthCare Technologies Inc.'),
#  (251, 'Garmin Ltd.'),
#  (251, 'Gartner, Inc.'),
#  (251, 'Gen Digital Inc.'),
#  (251, 'Generac Holdlings Inc.'),
#  (251, 'General Dynamics Corporation'),
#  (251, 'General Electric Company'),
#  (251, 'General Mills, Inc.'),
#  (251, 'General Motors Company'),
#  (251, 'Genuine Parts Company'),
#  (251, 'Gilead Sciences, Inc.'),
#  (251, 'Global Payments Inc.'),
#  (251, 'Globe Life Inc.'),
#  (251, 'Goldman Sachs Group, Inc. (The)'),
#  (251, 'HCA Healthcare, Inc.'),
#  (251, 'HP Inc.'),
#  (251, 'Halliburton Company'),
#  (251, 'Hartford Financial Services Gro'),
#  (251, 'Hasbro, Inc.'),
#  (251, 'Healthpeak Properties, Inc.'),
#  (251, 'Henry Schein, Inc.'),
#  (251, 'Hess Corporation'),
#  (251, 'Hewlett Packard Enterprise Comp'),
#  (251, 'Hilton Worldwide Holdings Inc.'),
#  (251, 'Hologic, Inc.'),
#  (251, 'Home Depot, Inc. (The)'),
#  (251, 'Honeywell International Inc.'),
#  (251, 'Hormel Foods Corporation'),
#  (251, 'Host Hotels'),
#  (251, 'Howmet Aerospace Inc.'),
#  (251, 'Humana Inc.'),
#  (251, 'Huntington Bancshares Incorpora'),
#  (251, 'Huntington Ingalls Industries, '),
#  (251, 'IDEX Corporation'),
#  (251, 'IDEXX Laboratories, Inc.'),
#  (251, 'IQVIA Holdings, Inc.'),
#  (251, 'Illinois Tool Works Inc.'),
#  (251, 'Illumina, Inc.'),
#  (251, 'Incyte Corporation'),
#  (251, 'Ingersoll Rand Inc.'),
#  (251, 'Insulet Corporation'),
#  (251, 'Intel Corporation'),
#  (251, 'Intercontinental Exchange Inc.'),
#  (251, 'International Business Machines'),
#  (251, 'International Flavors & Fragran'),
#  (251, 'International Paper Company'),
#  (251, 'Interpublic Group of Companies,'),
#  (251, 'Intuit Inc.'),
#  (251, 'Intuitive Surgical, Inc.'),
#  (251, 'Invesco Ltd'),
#  (251, 'Invitation Homes Inc.'),
#  (251, 'Iron Mountain Incorporated (Del'),
#  (251, 'J.B. Hunt Transport Services, I'),
#  (251, 'J.M. Smucker Company (The) New'),
#  (251, 'JP Morgan Chase & Co.'),
#  (251, 'Jack Henry & Associates, Inc.'),
#  (251, 'Jacobs Solutions Inc.'),
#  (251, 'Johnson & Johnson'),
#  (251, 'Johnson Controls International '),
#  (251, 'Juniper Networks, Inc.'),
#  (251, 'KLA Corporation'),
#  (251, 'Kellogg Company'),
#  (251, 'Keurig Dr Pepper Inc.'),
#  (251, 'KeyCorp'),
#  (251, 'Keysight Technologies Inc.'),
#  (251, 'Kimberly-Clark Corporation'),
#  (251, 'Kimco Realty Corporation (HC)'),
#  (251, 'Kinder Morgan, Inc.'),
#  (251, 'Kroger Company (The)'),
#  (251, 'L3Harris Technologies, Inc.'),
#  (251, 'LKQ Corporation'),
#  (251, 'Otis Worldwide Corporation'),
#  (251, 'PACCAR Inc.'),
#  (251, 'PNC Financial Services Group, I'),
#  (251, 'PPG Industries, Inc.'),
#  (251, 'PPL Corporation'),
#  (251, 'PTC Inc.'),
#  (251, 'Pacific Gas & Electric Co.'),
#  (251, 'Packaging Corporation of Americ'),
#  (251, 'Palo Alto Networks, Inc.'),
#  (251, 'Paramount Global'),
#  (251, 'Parker-Hannifin Corporation'),
#  (251, 'PayPal Holdings, Inc.'),
#  (251, 'Paychex, Inc.'),
#  (251, 'Paycom Software, Inc.'),
#  (251, 'Pentair plc.'),
#  (251, 'Pepsico, Inc.'),
#  (251, 'Pfizer, Inc.'),
#  (251, 'Philip Morris International Inc'),
#  (251, 'Phillips 66'),
#  (251, 'Pinnacle West Capital Corporati'),
#  (251, 'Pioneer Natural Resources Compa'),
#  (251, 'Pool Corporation'),
#  (251, 'Principal Financial Group Inc'),
#  (251, 'Procter & Gamble Company (The)'),
#  (251, 'Progressive Corporation (The)'),
#  (251, 'Prologis, Inc.'),
#  (251, 'Prudential Financial, Inc.'),
#  (251, 'Public Service Enterprise Group'),
#  (251, 'Public Storage'),
#  (251, 'PulteGroup, Inc.'),
#  (251, 'QUALCOMM Incorporated'),
#  (251, 'Qorvo, Inc.'),
#  (251, 'Quanta Services, Inc.'),
#  (251, 'Quest Diagnostics Incorporated'),
#  (251, 'RTX Corporation'),
#  (251, 'Ralph Lauren Corporation'),
#  (251, 'Raymond James Financial, Inc.'),
#  (251, 'Realty Income Corporation'),
#  (251, 'Regency Centers Corporation'),
#  (251, 'Regeneron Pharmaceuticals, Inc.'),
#  (251, 'Regions Financial Corporation'),
#  (251, 'Republic Services, Inc.'),
#  (251, 'ResMed Inc.'),
#  (251, 'Revvity, Inc.'),
#  (251, 'Robert Half Inc.'),
#  (251, 'Rockwell Automation, Inc.'),
#  (251, 'Rollins, Inc.'),
#  (251, 'Roper Technologies, Inc.'),
#  (251, 'Ross Stores, Inc.'),
#  (251, 'Royal Caribbean Cruises Ltd.'),
#  (251, 'S&P Global Inc.'),
#  (251, 'SBA Communications Corporation'),
#  (251, 'STERIS plc (Ireland)'),
#  (251, 'Salesforce, Inc.'),
#  (251, 'Schlumberger N.V.'),
#  (251, 'Seagate Technology Holdings PLC'),
#  (251, 'Sealed Air Corporation'),
#  (251, 'ServiceNow, Inc.'),
#  (251, 'Sherwin-Williams Company (The)'),
#  (251, 'Simon Property Group, Inc.'),
#  (251, 'Skyworks Solutions, Inc.'),
#  (251, 'Snap-On Incorporated'),
#  (251, 'SolarEdge Technologies, Inc.'),
#  (251, 'Southern Company (The)'),
#  (251, 'Southwest Airlines Company'),
#  (251, 'Stanley Black & Decker, Inc.'),
#  (251, 'Starbucks Corporation'),
#  (251, 'State Street Corporation'),
#  (251, 'Steel Dynamics, Inc.'),
#  (251, 'Stryker Corporation'),
#  (251, 'Synchrony Financial'),
#  (251, 'Synopsys, Inc.'),
#  (251, 'Sysco Corporation'),
#  (251, 'T-Mobile US, Inc.'),
#  (251, 'T. Rowe Price Group, Inc.'),
#  (251, 'TE Connectivity Ltd. New Switze'),
#  (251, 'TJX Companies, Inc. (The)'),
#  (251, 'Take-Two Interactive Software, '),
#  (251, 'Tapestry, Inc.'),
#  (251, 'Targa Resources, Inc.'),
#  (251, 'Target Corporation'),
#  (251, 'Teledyne Technologies Incorpora'),
#  (251, 'Teleflex Incorporated'),
#  (251, 'Teradyne, Inc.'),
#  (251, 'Tesla, Inc.'),
#  (251, 'Texas Instruments Incorporated'),
#  (251, 'Textron Inc.'),
#  (251, 'The AES Corporation'),
#  (251, 'The Bank of New York Mellon Cor'),
#  (251, 'The Cigna Group'),
#  (251, 'The Cooper Companies, Inc.'),
#  (251, 'The Hershey Company'),
#  (251, 'The Kraft Heinz Company'),
#  (251, 'The Travelers Companies, Inc.'),
#  (251, 'Thermo Fisher Scientific Inc'),
#  (251, 'Tractor Supply Company'),
#  (251, 'Trane Technologies plc'),
#  (251, 'Transdigm Group Incorporated'),
#  (251, 'Trimble Inc.'),
#  (251, 'Truist Financial Corporation'),
#  (251, 'Tyler Technologies, Inc.'),
#  (251, 'Tyson Foods, Inc.'),
#  (251, 'U.S. Bancorp'),
#  (251, 'UDR, Inc.'),
#  (251, 'Ulta Beauty, Inc.'),
#  (251, 'Union Pacific Corporation'),
#  (251, 'United Airlines Holdings, Inc.'),
#  (251, 'United Parcel Service, Inc.'),
#  (251, 'United Rentals, Inc.'),
#  (251, 'UnitedHealth Group Incorporated'),
#  (251, 'Universal Health Services, Inc.'),
#  (251, 'V.F. Corporation'),
#  (251, 'VICI Properties Inc.'),
#  (251, 'Valero Energy Corporation'),
#  (251, 'Ventas, Inc.'),
#  (251, 'VeriSign, Inc.'),
#  (251, 'Verisk Analytics, Inc.'),
#  (251, 'Verizon Communications Inc.'),
#  (251, 'Vertex Pharmaceuticals Incorpor'),
#  (251, 'Viatris Inc.'),
#  (251, 'Visa Inc.'),
#  (251, 'Vulcan Materials Company (Holdi'),
#  (251, 'W.R. Berkley Corporation'),
#  (251, 'W.W. Grainger, Inc.'),
#  (251, 'WEC Energy Group, Inc.'),
#  (251, 'Walgreens Boots Alliance, Inc.'),
#  (251, 'Walmart Inc.'),
#  (251, 'Walt Disney Company (The)'),
#  (251, 'Warner Bros. Discovery, Inc. - '),
#  (251, 'Waste Management, Inc.'),
#  (251, 'Waters Corporation'),
#  (251, 'Wells Fargo & Company'),
#  (251, 'Welltower Inc.'),
#  (251, 'West Pharmaceutical Services, I'),
#  (251, 'Western Digital Corporation'),
#  (251, 'Westinghouse Air Brake Technolo'),
#  (251, 'Westrock Company'),
#  (251, 'Weyerhaeuser Company'),
#  (251, 'Whirlpool Corporation'),
#  (251, 'Williams Companies, Inc. (The)'),
#  (251, 'Willis Towers Watson Public Lim'),
#  (251, 'Wynn Resorts, Limited'),
#  (251, 'Xcel Energy Inc.'),
#  (251, 'Xylem Inc.'),
#  (251, 'Yum! Brands, Inc.'),
#  (251, 'Zebra Technologies Corporation'),
#  (251, 'Zimmer Biomet Holdings, Inc.'),
#  (251, 'Zions Bancorporation N.A.'),
#  (251, 'Zoetis Inc.'),
#  (251, 'eBay Inc.')]

# %%
# List all dates
cur.execute(
    """
    SELECT DATE(date, 'unixepoch')
    FROM date
    """
).fetchall()
# Out:
# [('2022-07-01',),
#  ('2022-07-05',),
#  ('2022-07-06',),
#  ('2022-07-07',),
#  ('2022-07-08',),
#  ('2022-07-11',),
#  ('2022-07-12',),
#  ('2022-07-13',),
#  ('2022-07-14',),
#  ('2022-07-15',),
#  ('2022-07-18',),
#  ('2022-07-19',),
#  ('2022-07-20',),
#  ('2022-07-21',),
#  ('2022-07-22',),
#  ('2022-07-25',),
#  ('2022-07-26',),
#  ('2022-07-27',),
#  ('2022-07-28',),
#  ('2022-07-29',),
#  ('2022-08-01',),
#  ('2022-08-02',),
#  ('2022-08-03',),
#  ('2022-08-04',),
#  ('2022-08-05',),
#  ('2022-08-08',),
#  ('2022-08-09',),
#  ('2022-08-10',),
#  ('2022-08-11',),
#  ('2022-08-12',),
#  ('2022-08-15',),
#  ('2022-08-16',),
#  ('2022-08-17',),
#  ('2022-08-18',),
#  ('2022-08-19',),
#  ('2022-08-22',),
#  ('2022-08-23',),
#  ('2022-08-24',),
#  ('2022-08-25',),
#  ('2022-08-26',),
#  ('2022-08-29',),
#  ('2022-08-30',),
#  ('2022-08-31',),
#  ('2022-09-01',),
#  ('2022-09-02',),
#  ('2022-09-06',),
#  ('2022-09-07',),
#  ('2022-09-08',),
#  ('2022-09-09',),
#  ('2022-09-12',),
#  ('2022-09-13',),
#  ('2022-09-14',),
#  ('2022-09-15',),
#  ('2022-09-16',),
#  ('2022-09-19',),
#  ('2022-09-20',),
#  ('2022-09-21',),
#  ('2022-09-22',),
#  ('2022-09-23',),
#  ('2022-09-26',),
#  ('2022-09-27',),
#  ('2022-09-28',),
#  ('2022-09-29',),
#  ('2022-09-30',),
#  ('2022-10-03',),
#  ('2022-10-04',),
#  ('2022-10-05',),
#  ('2022-10-06',),
#  ('2022-10-07',),
#  ('2022-10-10',),
#  ('2022-10-11',),
#  ('2022-10-12',),
#  ('2022-10-13',),
#  ('2022-10-14',),
#  ('2022-10-17',),
#  ('2022-10-18',),
#  ('2022-10-19',),
#  ('2022-10-20',),
#  ('2022-10-21',),
#  ('2022-10-24',),
#  ('2022-10-25',),
#  ('2022-10-26',),
#  ('2022-10-27',),
#  ('2022-10-28',),
#  ('2022-10-31',),
#  ('2022-11-01',),
#  ('2022-11-02',),
#  ('2022-11-03',),
#  ('2022-11-04',),
#  ('2022-11-07',),
#  ('2022-11-08',),
#  ('2022-11-09',),
#  ('2022-11-10',),
#  ('2022-11-11',),
#  ('2022-11-14',),
#  ('2022-11-15',),
#  ('2022-11-16',),
#  ('2022-11-17',),
#  ('2022-11-18',),
#  ('2022-11-21',),
#  ('2022-11-22',),
#  ('2022-11-23',),
#  ('2022-11-25',),
#  ('2023-05-16',),
#  ('2023-05-17',),
#  ('2023-05-18',),
#  ('2023-05-19',),
#  ('2023-05-22',),
#  ('2023-05-23',),
#  ('2023-05-24',),
#  ('2023-05-25',),
#  ('2023-05-26',),
#  ('2023-05-30',),
#  ('2023-05-31',),
#  ('2023-06-01',),
#  ('2023-06-02',),
#  ('2023-06-05',),
#  ('2023-06-06',),
#  ('2023-06-07',),
#  ('2023-06-08',),
#  ('2023-06-09',),
#  ('2023-06-12',),
#  ('2023-06-13',),
#  ('2023-06-14',),
#  ('2023-06-15',),
#  ('2023-06-16',),
#  ('2023-06-20',),
#  ('2023-06-21',),
#  ('2023-06-22',),
#  ('2023-06-23',),
#  ('2023-06-26',),
#  ('2023-06-27',),
#  ('2023-06-28',),
#  ('2023-06-29',),
#  ('2023-06-30',),
#  ('2023-07-03',),
#  ('2023-07-05',),
#  ('2023-07-06',),
#  ('2023-07-07',),
#  ('2023-07-10',),
#  ('2023-07-11',),
#  ('2023-07-12',),
#  ('2023-07-13',),
#  ('2023-07-14',),
#  ('2023-07-17',),
#  ('2023-07-18',),
#  ('2023-07-19',),
#  ('2023-07-20',),
#  ('2023-07-21',),
#  ('2023-07-24',),
#  ('2023-07-25',),
#  ('2023-07-26',),
#  ('2023-07-27',),
#  ('2023-07-28',),
#  ('2023-07-31',),
#  ('2023-08-01',),
#  ('2023-08-02',),
#  ('2023-08-03',),
#  ('2023-08-04',),
#  ('2023-08-07',),
#  ('2023-08-08',),
#  ('2023-08-09',),
#  ('2023-08-10',),
#  ('2023-08-11',),
#  ('2023-08-14',),
#  ('2023-08-15',),
#  ('2023-08-16',),
#  ('2023-08-17',),
#  ('2023-08-18',)]

# %%
main_query = """
SELECT t.symbol,
    t.name,
    s.name,
    DATE(d.date, 'unixepoch'),
    p.open,
    p.high,
    p.low,
    p.close,
    p.volume,
    e.name,
    tt.name,
    c.iso_code
FROM price p
    JOIN ticker t ON p.ticker_id = t.id
    JOIN date d ON p.date_id = d.id
    JOIN sector s ON t.sector_id = s.id
    JOIN exchange e ON t.exchange_id = e.id
    JOIN currency c ON t.currency_id = c.id
    JOIN ticker_type tt ON t.ticker_type_id = tt.id
"""

# %%
cur.execute(main_query).fetchmany(3)
# Out:
# [('A',
#   'Agilent Technologies, Inc.',
#   'Healthcare',
#   '2022-07-01',
#   117.99027717779944,
#   118.95374810979271,
#   115.91434363539602,
#   118.4074478149414,
#   1119800,
#   'NYQ',
#   'EQUITY',
#   'USD'),
#  ('A',
#   'Agilent Technologies, Inc.',
#   'Healthcare',
#   '2022-07-05',
#   116.95727967718092,
#   119.86755454042228,
#   115.70576016770362,
#   119.74835968017578,
#   1484900,
#   'NYQ',
#   'EQUITY',
#   'USD'),
#  ('A',
#   'Agilent Technologies, Inc.',
#   'Healthcare',
#   '2022-07-06',
#   119.98675012194727,
#   121.51637582513143,
#   119.74836040002126,
#   120.36418914794922,
#   1642300,
#   'NYQ',
#   'EQUITY',
#   'USD')]

# %%
con.commit()
con.close()
